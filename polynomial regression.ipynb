# 2999996     2999996  35.259306  23.464772   16.497632     -6.212948
# 2999997     2999997  24.991475  22.319838    9.598257    -30.795183
# 2999998     2999998  35.492639  28.065057   33.218462      0.230913
# 2999999     2999999  13.197184  24.286192   14.259269    -90.152097
#
#            new_speed    delta_x
# 0           0.000000   0.000000
# 1           2.636817   0.258755
# 2           3.140367   0.309484
# 3          11.908205   1.187621
# 4          15.437908   1.542429
# 5          10.758856   1.071033
# 6           9.561361   0.951275
# 7         -13.381347   0.842625
# 8          21.785972   2.175358
# 9          21.810673   2.668742
# 10         15.226255   1.517994
# 11         24.651257   2.487385
# 12         18.247781   1.820499
# 13          8.161224   0.811183
# 14          6.548497   0.650430
# 15          2.091780   0.204187
# 16         11.701447   1.198467
# 17         12.759068   1.271081
# 18         14.321172   1.427401
# 19         15.983644   1.609576
# 20         21.100166   2.106413
# 21         31.574270   3.222849
# 22          7.309053   0.725962
# 23          1.778578   0.172886
# 24        -86.604630  -3.300551
# 25         23.987587   2.686939
# 26         18.233932   1.826160
# 27          0.894320   0.085952
# 28          8.575639   0.855411
# 29         17.982394   1.811406
# ...              ...        ...
# 2999970 -1586.082780 -77.808374
# 2999971    13.034943   1.312682
# 2999972     1.984554   0.193829
# 2999973   -93.634830  -3.142283
# 2999974    26.139256   2.629741
# 2999975    11.398102   1.134967
# 2999976    33.124725   3.378295
# 2999977    31.504835   3.151998
# 2999978    14.594158   1.455160
# 2999979    14.050636   1.416220
# 2999980    17.470090   1.742582
# 2999981    18.394586   2.566637
# 2999982    18.426789   2.603300
# 2999983     3.656456   0.360696
# 2999984    17.130366   2.487054
# 2999985     5.317447   0.534838
# 2999986    -3.462738   1.033209
# 2999987    25.323490   2.625625
# 2999988     3.923307   0.387340
# 2999989     1.592017   0.154253
# 2999990    10.893278   1.084448
# 2999991    27.126599   2.773704
# 2999992     6.104581   0.605569
# 2999993    26.677049   2.665869
# 2999994    19.889949   2.113912
# 2999995    14.833687   1.478726
# 2999996    22.843477   2.315412
# 2999997    19.240320   2.078008
# 2999998    28.088148   2.807660
# 2999999    15.270982   1.977859
#
# [3000000 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
x_poly = poly_reg.fit_transform(x)
poly_reg.fit(x_poly, y)

lin_reg2 = LinearRegression()
lin_reg2.fit(x_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Linear
plt.scatter(x, y, color = 'blue') 
  
plt.plot(x, lin_reg.predict(x), color = 'red') 
plt.title('Linear Regression') 
plt.xlabel('gap') 
plt.ylabel('speed') 
  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-15f2daf350f7> in <module>
#       2 plt.scatter(x, y, color = 'blue')
#       3
# ----> 4 plt.plot(x, lin_reg.predict(x), color = 'red')
#       5 plt.title('Linear Regression')
#       6 plt.xlabel('gap')
#
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     204         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     205         return safe_sparse_dot(X, self.coef_.T,
# --> 206                                dense_output=True) + self.intercept_
#     207
#     208     def predict(self, X):
#
# //anaconda3/lib/python3.7/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     140         return ret
#     141     else:
# --> 142         return np.dot(a, b)
#     143
#     144
#
# ValueError: shapes (3000000,1) and (5,) not aligned: 1 (dim 1) != 5 (dim 0)

# %%
plt.scatter(x, y, color = 'blue') 
  
plt.plot(x, lin_reg2.predict(poly_reg.fit_transform(x)), color = 'red') 
plt.title('Polynomial Regression') 
plt.xlabel('gap') 
plt.ylabel('speed') 
  
plt.show()
